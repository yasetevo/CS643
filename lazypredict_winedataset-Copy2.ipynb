# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
#from collections import Counter
# %matplotlib inline

import pyforest

import warnings
warnings.filterwarnings("ignore")

from sklearn import metrics
from sklearn.metrics import accuracy_score

# %%
lazy_imports()
# Out:
# ['import sklearn',
#  'import pickle',
#  'from sklearn.ensemble import RandomForestClassifier',
#  'from sklearn.ensemble import RandomForestRegressor',
#  'import datetime as dt',
#  'import matplotlib as mpl',
#  'from sklearn.model_selection import train_test_split',
#  'import numpy as np',
#  'import plotly.graph_objs as go',
#  'from sklearn.preprocessing import OneHotEncoder',
#  'import statistics',
#  'import plotly.express as px',
#  'import glob',
#  'import gensim',
#  'import os',
#  'import pydot',
#  'import xgboost as xgb',
#  'from pathlib import Path',
#  'from sklearn import svm',
#  'from sklearn.ensemble import GradientBoostingClassifier',
#  'import nltk',
#  'from pyspark import SparkContext',
#  'import sys',
#  'import dash',
#  'import tensorflow as tf',
#  'import matplotlib.pyplot as plt',
#  'import seaborn as sns',
#  'import bokeh',
#  'from sklearn.ensemble import GradientBoostingRegressor',
#  'import awswrangler as wr',
#  'from dask import dataframe as dd',
#  'import lightgbm as lgb',
#  'import pandas as pd',
#  'import plotly as py',
#  'from sklearn.feature_extraction.text import TfidfVectorizer',
#  'from openpyxl import load_workbook',
#  'import re',
#  'import altair as alt',
#  'import tqdm',
#  'import spacy',
#  'from sklearn.manifold import TSNE',
#  'import keras']

# %%
X = pd.read_excel('Uneven Resampling.xlsx')

# %%
del X['Unnamed: 0'] 
X.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           10.4             0.440         0.42             1.5      0.145
# 1           10.4             0.440         0.42             1.5      0.145
# 2           11.6             0.580         0.66             2.2      0.074
# 3            8.3             1.020         0.02             3.4      0.084
# 4            7.1             0.875         0.05             5.7      0.082
#
#    free sulfur dioxide  total sulfur dioxide  density     p  sulphates  \
# 0                 34.0                  48.0  0.99832  3.38       0.86
# 1                 34.0                  48.0  0.99832  3.38       0.86
# 2                 10.0                  47.0  1.00080  3.25       0.57
# 3                  6.0                  11.0  0.99892  3.48       0.49
# 4                  3.0                  14.0  0.99808  3.40       0.52
#
#    alcohol  quality
# 0      9.9        3
# 1      9.9        3
# 2      9.0        3
# 3     11.0        3
# 4     10.2        3

# %%
Y= pd.read_csv('ValidationDataset.csv', sep=';', skiprows=1, 
                names=['fixed acidity', 'volatile acidity','citric acid', 'residual sugar', 'chlorides','free sulfur dioxide' , 'total sulfur dioxide','density','pH', 'sulphates','alcohol','quality'])

# %%
Y.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                   11                    34   0.9978  3.51       0.56
# 1                   25                    67   0.9968  3.20       0.68
# 2                   15                    54   0.9970  3.26       0.65
# 3                   17                    60   0.9980  3.16       0.58
# 4                   11                    34   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
X_train = X.iloc[:,0:11]

# %%
X_train.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           10.4             0.440         0.42             1.5      0.145
# 1           10.4             0.440         0.42             1.5      0.145
# 2           11.6             0.580         0.66             2.2      0.074
# 3            8.3             1.020         0.02             3.4      0.084
# 4            7.1             0.875         0.05             5.7      0.082
#
#    free sulfur dioxide  total sulfur dioxide  density     p  sulphates  \
# 0                 34.0                  48.0  0.99832  3.38       0.86
# 1                 34.0                  48.0  0.99832  3.38       0.86
# 2                 10.0                  47.0  1.00080  3.25       0.57
# 3                  6.0                  11.0  0.99892  3.48       0.49
# 4                  3.0                  14.0  0.99808  3.40       0.52
#
#    alcohol
# 0      9.9
# 1      9.9
# 2      9.0
# 3     11.0
# 4     10.2

# %%
y_train = X.iloc[:,11]

# %%
y_train.head(5)
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    3
# Name: quality, dtype: int64

# %%
y_train = pd.DataFrame(y_train)

# %%
X_test = Y.iloc[:,0:11]
y_test = Y.iloc[:,11]

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
import lazypredict
from lazypredict.Supervised import LazyClassifier

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True)
models, predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [00:03<00:00,  8.82it/s]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# LogisticRegression                 0.52               0.52    None      0.52
# SGDClassifier                      0.51               0.42    None      0.51
# PassiveAggressiveClassifier        0.31               0.39    None      0.34
# BaggingClassifier                  0.55               0.36    None      0.55
# CalibratedClassifierCV             0.54               0.35    None      0.53
# NearestCentroid                    0.31               0.33    None      0.34
# ExtraTreeClassifier                0.49               0.33    None      0.50
# RandomForestClassifier             0.53               0.32    None      0.52
# ExtraTreesClassifier               0.54               0.32    None      0.51
# GaussianNB                         0.44               0.32    None      0.49
# Perceptron                         0.44               0.31    None      0.46
# BernoulliNB                        0.51               0.28    None      0.51
# LabelSpreading                     0.49               0.27    None      0.50
# LabelPropagation                   0.49               0.27    None      0.50
# LinearDiscriminantAnalysis         0.50               0.27    None      0.51
# XGBClassifier                      0.50               0.27    None      0.50
# LinearSVC                          0.54               0.26    None      0.51
# QuadraticDiscriminantAnalysis      0.44               0.25    None      0.46
# LGBMClassifier                     0.52               0.23    None      0.50
# KNeighborsClassifier               0.48               0.23    None      0.50
# RidgeClassifier                    0.55               0.22    None      0.50
# RidgeClassifierCV                  0.55               0.22    None      0.50
# SVC                                0.54               0.22    None      0.50
# DecisionTreeClassifier             0.44               0.20    None      0.45
# AdaBoostClassifier                 0.49               0.20    None      0.43
# DummyClassifier                    0.26               0.11    None      0.28
#
#                                Time Taken
# Model
# LogisticRegression                   0.06
# SGDClassifier                        0.03
# PassiveAggressiveClassifier          0.02
# BaggingClassifier                    0.07
# CalibratedClassifierCV               1.32
# NearestCentroid                      0.01
# ExtraTreeClassifier                  0.01
# RandomForestClassifier               0.27
# ExtraTreesClassifier                 0.18
# GaussianNB                           0.01
# Perceptron                           0.01
# BernoulliNB                          0.01
# LabelSpreading                       0.08
# LabelPropagation                     0.06
# LinearDiscriminantAnalysis           0.01
# XGBClassifier                        0.23
# LinearSVC                            0.30
# QuadraticDiscriminantAnalysis        0.01
# LGBMClassifier                       0.30
# KNeighborsClassifier                 0.02
# RidgeClassifier                      0.01
# RidgeClassifierCV                    0.02
# SVC                                  0.07
# DecisionTreeClassifier               0.02
# AdaBoostClassifier                   0.12
# DummyClassifier                      0.01

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)

# %%
print('Evaluation Metrics – Random Forest:')
print('Accuracy: ' + str(metrics.accuracy_score(y_test, y_pred)))
print('F1 Score: ' + str(metrics.f1_score(y_test, y_pred, average='macro')))

# %%
rf.get_params()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(max_features='auto', oob_score=True, random_state=1, n_jobs=-1)

param_grid = { "criterion" : ["gini", "entropy"], "min_samples_leaf" : [1, 5, 10], "min_samples_split" : [2, 4, 10, 12, 16], "n_estimators": [50, 100, 400, 700, 1000]}

gs = GridSearchCV(estimator=rf, param_grid=param_grid, scoring='accuracy', cv=3, n_jobs=-1)

gs = gs.fit(X_train,y_train)

# %%
print(gs.best_score_)
print(gs.best_params_)

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(criterion='gini', 
                             n_estimators=100,
                             min_samples_split=2,
                             min_samples_leaf=1,
                             max_features='auto',
                             oob_score=True,
                             random_state=1,
                             n_jobs=None)
rf.fit(X_train, y_train)
print("%.4f" % rf.oob_score_)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

y_pred = rf.predict(X_test)

print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
print(accuracy_score(y_test, y_pred))

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()
model_res = clf.fit(X_train, y_train)

# %%
y_pred = clf.predict(X_test)

# %%
print('Evaluation Metrics – Random Forest:')
print('Accuracy: ' + str(metrics.accuracy_score(y_test, y_pred)))
print('F1 Score: ' + str(metrics.f1_score(y_test, y_pred, average='macro')))

# %%
# Create first pipeline for base without reducing features.

#pipe = Pipeline([('classifier' , RandomForestClassifier())])
# pipe = Pipeline([('classifier', RandomForestClassifier())])

# Create param grid.
clf = LogisticRegression()

param_grid = {
     'penalty' : ['l1', 'l2'],
    'C' : np.logspace(-4, 4, 20),
    'solver' : ['liblinear', 'newton-cg']
}

# Create grid search object

clf = GridSearchCV(estimator=clf, param_grid = param_grid, cv = 5, verbose=True, n_jobs=-1)

# Fit on data

best_clf = clf.fit(X_train, y_train)

# %%
print(clf.best_score_)
print(clf.best_params_)

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier( bootstrap=True,
                             ccp_alpha= 0.0,
                             class_weight= None,
                             criterion= 'gini',
                             max_depth= None,
                             max_features= 'auto',
                             max_leaf_nodes= None,
                             max_samples= None,
                             min_impurity_decrease= 0.0,
                             min_impurity_split= None,
                             min_samples_leaf= 1,
                             min_samples_split= 2,
                             min_weight_fraction_leaf= 0.0,
                             n_estimators= 100,
                             n_jobs= None,
                             oob_score=True,
                             random_state= None,
                             verbose= 0,
                             warm_start = False)
rf.fit(X_train, y_train)
print("%.4f" % rf.oob_score_)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

y_pred = rf.predict(X_test)

print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
print(accuracy_score(y_test, y_pred))

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, make_scorer
from sklearn.model_selection import cross_val_score
#from sklearn.preprocessing import Imputer
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline

# Custom scorer for cross validation
scorer = make_scorer(f1_score, greater_is_better=True, average = 'macro')

# %%
cv_score = cross_val_score(rf, X_train, y_train, cv = 4, scoring = scorer)

print(f'10 Fold Cross Validation F1 Score = {round(cv_score.mean(), 4)} with std = {round(cv_score.std(), 4)}')

# %%
cv_score = cross_val_score(rf, X_train, y_train, cv = 4, scoring = scorer)

print(f'10 Fold Cross Validation F1 Score = {round(cv_score.mean(), 4)} with std = {round(cv_score.std(), 4)}')
